# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Suppress Pandas SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv('../data/states_edu.csv')
df.head() # Parts of the data
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
# Rename columns as what we've done in the tutorial
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)

# %%
# Since in this setting, we are interested in Grade 8 Math, we drop all the rows where the Grade 8 Math score is missing
df.dropna(subset=['AVG_MATH_8_SCORE'], inplace=True)

df.isna().sum() # Take a look at the summary on the numbers of NA values for each variable, we decide to fix the NA values for ENROLL_PRIMARY
# variable since it might affect our accessment of AVG_MATH_8_SCORE (what we are interested in)
# Out:
# PRIMARY_KEY                       0
# STATE                             0
# YEAR                              0
# ENROLL_ALL_EST                  205
# TOTAL_REVENUE                   163
# FEDERAL_REVENUE                 163
# STATE_REVENUE                   163
# LOCAL_REVENUE                   163
# TOTAL_EXPENDITURE               163
# INSTRUCTION_EXPENDITURE         163
# SUPPORT_SERVICES_EXPENDITURE    163
# OTHER_EXPENDITURE               205
# CAPITAL_OUTLAY_EXPENDITURE      163
# ENROLL_PREK                      84
# ENROLL_KINDER                    74
# ENROLL_4                         74
# ENROLL_8                         74
# ENROLL_12                        74
# ENROLL_PRIMARY                  205
# ENROLL_HS                       154
# ENROLL_ALL                       74
# AVG_MATH_4_SCORE                 38
# AVG_MATH_8_SCORE                  0
# AVG_READING_4_SCORE              81
# AVG_READING_8_SCORE             124
# dtype: int64

# %%
# First let's check if the individual enrollments actually sum up to total enrollment
(df["ENROLL_ALL"]-df["ENROLL_PREK"]-df["ENROLL_KINDER"]-df["ENROLL_PRIMARY"]-df["ENROLL_HS"]).describe()
# Out:
# count       394.000000
# mean       4945.781726
# std       17269.335326
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%        1012.000000
# max      147954.000000
# dtype: float64

# %%
# enrollment differences as a percent
((df["ENROLL_ALL"]-df["ENROLL_PREK"]-df["ENROLL_KINDER"]-df["ENROLL_PRIMARY"]-df["ENROLL_HS"])/df["ENROLL_ALL"]*100).describe()
# Out:
# count    394.000000
# mean       0.420306
# std        1.090873
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.188212
# max        7.702014
# dtype: float64

# %%
# Like what we've concluded in the tutorial, it's a reasonable way to estimate ENROLL_PRIMARY by substracting the values of the other three variables from ENROLL_ALL
df["ENROLL_PRIMARY"] = df["ENROLL_PRIMARY"].fillna(df["ENROLL_ALL"]-df["ENROLL_PREK"]-df["ENROLL_KINDER"]-df["ENROLL_HS"])
df["ENROLL_PRIMARY"].isna().sum() # It does help to fix some NA values!
# Out:
# 154

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: AVG_MATH_8_SCORE

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
year = df.groupby("YEAR")
len(year) # 13 years
# Out:
# 13

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
boo1 = df[df["STATE"] == "MICHIGAN"]["AVG_MATH_8_SCORE"].mean() > df[df["STATE"] == "OHIO"]["AVG_MATH_8_SCORE"].mean()

if boo1:
    print("MICHIGAN")
else:
    print("OHIO") # The Ohio state has the higher average outcome score
# Out:
# OHIO

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
df[df["YEAR"] == 2019]["AVG_MATH_8_SCORE"].mean()
# Out:
# 281.2641509433962

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
state = df.groupby("STATE")
state["AVG_MATH_8_SCORE"].max()
# Out:
# STATE
# ALABAMA                 269.0
# ALASKA                  283.0
# ARIZONA                 283.0
# ARKANSAS                279.0
# CALIFORNIA              277.0
# COLORADO                292.0
# CONNECTICUT             289.0
# DELAWARE                284.0
# DISTRICT_OF_COLUMBIA    269.0
# DODEA                   293.0
# FLORIDA                 281.0
# GEORGIA                 281.0
# HAWAII                  281.0
# IDAHO                   287.0
# ILLINOIS                285.0
# INDIANA                 288.0
# IOWA                    286.0
# KANSAS                  290.0
# KENTUCKY                282.0
# LOUISIANA               273.0
# MAINE                   289.0
# MARYLAND                288.0
# MASSACHUSETTS           301.0
# MICHIGAN                280.0
# MINNESOTA               295.0
# MISSISSIPPI             274.0
# MISSOURI                286.0
# MONTANA                 293.0
# NATIONAL                285.0
# NEBRASKA                288.0
# NEVADA                  278.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
df['INSTRUCTION_EXPENDITURE_PER_STUDENT'] = df['INSTRUCTION_EXPENDITURE'] / df['ENROLL_ALL']
df['SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT'] = df['SUPPORT_SERVICES_EXPENDITURE'] / df['ENROLL_ALL']

# %% [markdown]
# Feature engineering justification: As discussed in the tutorial, the variation in population across the states reduces the informativeness of the values of the INSTRUCTION_EXPENDITURE and SUPPORT_SERVICES_EXPENDITURE variables, thus encouraging us to utilize new quantitative statistics such as INSTRUCTION_EXPENDITURE_PER_STUDENT and SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT.

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
year["AVG_MATH_8_SCORE"].mean().plot()
plt.ylabel('SCORE')
plt.title('8th Grade Math Score Over Time')
# Out:
# Text(0.5, 1.0, '8th Grade Math Score Over Time')

# %% [markdown]
# It turns out that, starting from 1990, the 8th grade math score keeps growing steadily till somepoint around 2012-2013 and then begins to decrease.

# %% [markdown]
# **Visualization 2**

# %%
df.plot.scatter(x = "INSTRUCTION_EXPENDITURE_PER_STUDENT", y = "AVG_MATH_8_SCORE", alpha = 0.6)
df.plot.scatter(x = "SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT", y = "AVG_MATH_8_SCORE", alpha = 0.6)
# Out:
# <Axes: xlabel='SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT', ylabel='AVG_MATH_8_SCORE'>

# %% [markdown]
# It shows that the 8th grade math score is positively correlated with both the instruction expenditure per student and support service expenditure per student. In particular, instruction expenditure per student seems to have a more significant effect on 8th grade math score.

# %%
df.plot.scatter(x = "ENROLL_8", y = "AVG_MATH_8_SCORE", alpha = 0.6)
df.plot.scatter(x = "ENROLL_PRIMARY", y = "AVG_MATH_8_SCORE", alpha = 0.6)
# Out:
# <Axes: xlabel='ENROLL_PRIMARY', ylabel='AVG_MATH_8_SCORE'>

# %% [markdown]
# There are no significant relationships between the number of enrollment for the 8th grade, the number of enrollment for the primary school and 8th grade math score.

# %%
df.plot.scatter(x = "AVG_MATH_4_SCORE", y = "AVG_MATH_8_SCORE", alpha = 0.6)
df.plot.scatter(x = "AVG_READING_8_SCORE", y = "AVG_MATH_8_SCORE", alpha = 0.6)
# Out:
# <Axes: xlabel='AVG_READING_8_SCORE', ylabel='AVG_MATH_8_SCORE'>

# %% [markdown]
# It shows that the 4th grade math score and 8th grade reading score are strongly correlated with 8th grade math score.

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['INSTRUCTION_EXPENDITURE_PER_STUDENT','SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT','AVG_MATH_4_SCORE','AVG_READING_8_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_8_SCORE']
# Out:
# 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
# R^2
model.score(X_test, y_test)
# Out:
# 0.9220823083420956

# %%
# mean absolute error
np.mean(np.abs(y_pred-y_test))
# Out:
# 1.7994645612450098

# %% [markdown]
# The R^2 value is close to 1 and the mean absolute error is relatively small, from which we know that the model fits the data pretty well.

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = "AVG_MATH_4_SCORE"

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 8 score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = "AVG_MATH_4_SCORE"

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('Math 8 score')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# Given the data, I first skim through the first few rows of the data set and decide to investigate into the variable AVG_MATH_8_SCORE. As a data cleaning process, I renamed the columns to make them more intuitive and replaced some NA values of the variable ENROLL_PRIMARY with estimations based on other related variables. After that, I did EDA and feature engineering. Considering the variation in population across the states, I combined several variables to create more representative ones like INSTRUCTION_EXPENDITURE_PER_STUDENT and SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT.
# To get a sense of the relationships between the chosen response variable and other predictors, I generated several plots and found that the 8th grade math score grows over-time but shows a trend of descending in recent years. Also, the instruction expenditure per student, support service expenditure per student, the 4th grade math score and 8th grade reading score are positively correlated with 8th grade math score. In particular, the relations between the latter two and the 8th grade math score are quite strong.
# Moreover, I used linear regression model to fit the data with 4 input variables 'INSTRUCTION_EXPENDITURE_PER_STUDENT','SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT','AVG_MATH_4_SCORE','AVG_READING_8_SCORE' and the output variable 'AVG_MATH_8_SCORE'. Both the metrics (R^2 value and mean absolute error) and visualizations indicate that the model fits the data pretty well.
